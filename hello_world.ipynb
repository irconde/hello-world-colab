# %% [markdown]
# <a href="https://colab.research.google.com/github/irconde/hello-world-colab/blob/colab/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment 1**
#
# This is the first assignment of the ABP course

# %%
print("Hello world")
# Out:
# Hello world
